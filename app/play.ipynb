# %%
from nltk.corpus import stopwords

# %%
len(stopwords.words('english'))
# Out:
# 179

# %%
path = input('input file path:')

# %%
import pandas as pd
data = pd.read_csv('/Users/kun/code/kun1887/TwitPol/raw_data/test.csv')
# Out:
#               Tweet ID Date Created  \
# 0  1136821167644389376   2019-06-07
# 1  1136810151191678977   2019-06-07
# 2  1136793236788224001   2019-06-07
# 3  1136771002468360194   2019-06-06
# 4  1136761853391069184   2019-06-06
# 5  1136739063422230541   2019-06-06
# 6  1136693489243217921   2019-06-06
#
#                                                Tweet  \
# 0  Yes, Mr. President. There are, to borrow your ...
# 1  It's always good to be in Duluth! Thanks to ev...
# 2  With Fargo Mayor Tim Mahoney at the @790KFGO p...
# 3  Years later we still don't have all the answer...
# 4  You give me a run for my money, @HeidiHeitkamp...
# 5  What a great gathering in Fargo, North Dakota!...
# 6  Election security has never been (and must nev...
#
#                                          Clean_tweet  Polarity  Subjectivity  \
# 0  President There borrow your phrase HUGE change...  0.006667      0.513333
# 1  always good Duluth Thanks everyone came Hoops ...  0.450000      0.400000
# ...

# %%
int(0.3 * 121)
# Out:
# 36
